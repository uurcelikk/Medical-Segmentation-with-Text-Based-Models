# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !git clone https://github.com/uurcelikk/UNeXt-pytorch.git
# Out:
# Cloning into 'UNeXt-pytorch'...
# remote: Enumerating objects: 5532, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 5532 (delta 26), reused 57 (delta 21), pack-reused 5465
# Receiving objects: 100% (5532/5532), 688.02 MiB | 25.43 MiB/s, done.
# Resolving deltas: 100% (1718/1718), done.
# Updating files: 100% (5477/5477), done.

# %%
# %cd UNeXt-pytorch
# Out:
# /kaggle/working/UNeXt-pytorch

# %%
# !pip install timm
# !pip install opencv-python

# %%
# !pip install -U openmim
# !mim install mmcv
# Out:
# ...
#   Obtaining dependency information for openmim from https://files.pythonhosted.org/packages/00/b3/95531cee452028869d0e08974561f83e9c256c98f62c7a45a51893a61c54/openmim-0.3.9-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for opendatalab from https://files.pythonhosted.org/packages/10/82/28fa3a91b7c4852fbad9ad32c7b49e4b1e212ab7ccf7296736da0935070d/opendatalab-0.0.10-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for openxlab from https://files.pythonhosted.org/packages/5b/75/090abd2708bb4590da4e9bdd14a6cf0c495d90c930c82b5de65557486216/openxlab-0.0.32-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.5 MB/s eta 0:00:00
# ...

# %%
# !python train.py --dataset /kaggle/working/UNeXt-pytorch/Segment --arch UNext --name train --img_ext .png --mask_ext .png --lr 0.0001 --epochs 500 --input_w 512 --input_h 512 --b 8
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# --------------------
# name: train
# epochs: 500
# batch_size: 8
# arch: UNext
# deep_supervision: False
# input_channels: 3
# num_classes: 1
# input_w: 512
# input_h: 512
# loss: BCEDiceLoss
# dataset: /kaggle/working/UNeXt-pytorch/Segment
# img_ext: .png
# mask_ext: .png
# optimizer: Adam
# lr: 0.0001
# momentum: 0.9
# weight_decay: 0.0001
# nesterov: False
# scheduler: CosineAnnealingLR
# min_lr: 1e-05
# factor: 0.1
# patience: 2
# milestones: 1,2
# gamma: 0.6666666666666666
# early_stopping: -1
# cfg: None
# num_workers: 4
# --------------------
# Epoch [0/500]
# ...
# 100%|███| 69/69 [00:05<00:00, 13.36it/s, loss=0.983, iou=3.95e-10, dice=7.9e-10]
# loss 1.1193 - iou 0.0181 - val_loss 0.9832 - val_iou 0.0000
# => saved best model
# ...
